# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import psycopg2
from sqlalchemy import create_engine

# %%
conn = create_engine('postgresql://postgres:pikachu@localhost:5432/booksrap').connect()
conn

# %%
dfs = pd.read_sql('bobs',conn)
dfs
# Out:
#                                                   link  \
# 0                 a-light-in-the-attic_1000/index.html
# 1                    tipping-the-velvet_999/index.html
# 2                            soumission_998/index.html
# 3                         sharp-objects_997/index.html
# 4    sapiens-a-brief-history-of-humankind_996/index...
# ..                                                 ...
# 176     poems-that-make-grown-women-cry_824/index.html
# 177                    nightingale-sing_823/index.html
# 178          night-sky-with-exit-wounds_822/index.html
# 179                         mrs-houdini_821/index.html
# 180                                               tape
#
#                                      title   price     stock
# 0                     A Light in the Attic  £51.77  In stock
# 1                       Tipping the Velvet  £53.74  In stock
# 2                               Soumission  £50.10  In stock
# ...

# %%
plt.plot(dfs['price'])
import random
lst = [random.randint(0,100) for i in range(len(dfs))]
dfs.insert(1,column='Val',value=lst)
dfs
# Out:
#                                                   link  Val  \
# 0                 a-light-in-the-attic_1000/index.html   32
# 1                    tipping-the-velvet_999/index.html   27
# 2                            soumission_998/index.html   32
# 3                         sharp-objects_997/index.html   80
# 4    sapiens-a-brief-history-of-humankind_996/index...    6
# ..                                                 ...  ...
# 176     poems-that-make-grown-women-cry_824/index.html    7
# 177                    nightingale-sing_823/index.html   48
# 178          night-sky-with-exit-wounds_822/index.html   51
# 179                         mrs-houdini_821/index.html   84
# 180                                               tape   36
#
#                                      title   price     stock
# 0                     A Light in the Attic  £51.77  In stock
# 1                       Tipping the Velvet  £53.74  In stock
# ...

# %%
dfs['Val'].plot()
# Out:
# <AxesSubplot:>

# %%
import random
l = [100,200,300]
lst = [random.choice(l) for i in range(len(dfs))]
dfs.insert(2,column='ch',value=lst)
dfs
# Out:
#                                                   link  Val   ch  \
# 0                 a-light-in-the-attic_1000/index.html   32  300
# 1                    tipping-the-velvet_999/index.html   27  300
# 2                            soumission_998/index.html   32  100
# 3                         sharp-objects_997/index.html   80  300
# 4    sapiens-a-brief-history-of-humankind_996/index...    6  100
# ..                                                 ...  ...  ...
# 176     poems-that-make-grown-women-cry_824/index.html    7  300
# 177                    nightingale-sing_823/index.html   48  300
# 178          night-sky-with-exit-wounds_822/index.html   51  300
# 179                         mrs-houdini_821/index.html   84  200
# 180                                               tape   36  300
#
#                                      title   price     stock
# 0                     A Light in the Attic  £51.77  In stock
# 1                       Tipping the Velvet  £53.74  In stock
# ...

# %%
dfs['ch'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dfs = pd.read_sql_table('bobs',conn)

# %%
sql = "select stock from bobs where stock !='In stock'"
pd.read_sql_query(sql,conn)
# Out:
# Empty DataFrame
# Columns: [stock]
# Index: []

# %%
dic = {'link':'tape','title':'xes','price':'£30.25','stock':'In stock'}
dfs.append(dic, ignore_index = True)
# Out:
# C:\Users\Prabh\AppData\Local\Temp\ipykernel_20400\33076274.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfs.append(dic, ignore_index = True)
#                                                   link  \
# 0                 a-light-in-the-attic_1000/index.html
# 1                    tipping-the-velvet_999/index.html
# 2                            soumission_998/index.html
# 3                         sharp-objects_997/index.html
# 4    sapiens-a-brief-history-of-humankind_996/index...
# ..                                                 ...
# 176     poems-that-make-grown-women-cry_824/index.html
# 177                    nightingale-sing_823/index.html
# 178          night-sky-with-exit-wounds_822/index.html
# 179                         mrs-houdini_821/index.html
# 180                                               tape
#
#                                      title   price     stock
# ...

# %%
d = {'link':['tape'],'title':['xes'],'price':['£30.25'],'stock':['In stock']}
dfs2 = pd.DataFrame(d)
dfs2
# Out:
#    link title   price     stock
# 0  tape   xes  £30.25  In stock

# %%
new_df= pd.concat([dfs,dfs2], ignore_index = True)
new_df
# Out:
#                                                   link  \
# 0                 a-light-in-the-attic_1000/index.html
# 1                    tipping-the-velvet_999/index.html
# 2                            soumission_998/index.html
# 3                         sharp-objects_997/index.html
# 4    sapiens-a-brief-history-of-humankind_996/index...
# ..                                                 ...
# 176     poems-that-make-grown-women-cry_824/index.html
# 177                    nightingale-sing_823/index.html
# 178          night-sky-with-exit-wounds_822/index.html
# 179                         mrs-houdini_821/index.html
# 180                                               tape
#
#                                      title   price     stock
# 0                     A Light in the Attic  £51.77  In stock
# 1                       Tipping the Velvet  £53.74  In stock
# 2                               Soumission  £50.10  In stock
# ...

# %%
dfs2.to_sql(name='bobs',con=conn,index=False,if_exists='append')
# Out:
# 1
