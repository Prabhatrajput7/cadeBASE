# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
daat = data.DataReader(name= 'BB',data_source='yahoo',start='2007-01-01',end='2020-12-31')
daat
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998
# 2007-01-08  48.410000  46.606667  47.283333  47.386665  38547300.0  47.386665
# 2007-01-09  47.666668  43.263332  47.570000  43.666668  74142000.0  43.666668
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-24   7.240000   7.050000   7.120000   7.060000   6088300.0   7.060000
# 2020-12-28   7.130000   6.850000   7.100000   6.880000   9820100.0   6.880000
# 2020-12-29   7.000000   6.680000   6.980000   6.770000  11284200.0   6.770000
# 2020-12-30   6.810000   6.600000   6.790000   6.670000   9434900.0   6.670000
# 2020-12-31   6.800000   6.630000   6.680000   6.630000   7530600.0   6.630000
#
# [3525 rows x 6 columns]

# %%
daat['Open'].plot();

# %%
daat.plot();

# %%
daat.plot(y='Open');

# %%
daat[['Open','Close']].plot();

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-dark')

# %%
daat[['Open','Close']].plot();

# %%
daat
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998
# 2007-01-08  48.410000  46.606667  47.283333  47.386665  38547300.0  47.386665
# 2007-01-09  47.666668  43.263332  47.570000  43.666668  74142000.0  43.666668
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-24   7.240000   7.050000   7.120000   7.060000   6088300.0   7.060000
# 2020-12-28   7.130000   6.850000   7.100000   6.880000   9820100.0   6.880000
# 2020-12-29   7.000000   6.680000   6.980000   6.770000  11284200.0   6.770000
# 2020-12-30   6.810000   6.600000   6.790000   6.670000   9434900.0   6.670000
# 2020-12-31   6.800000   6.630000   6.680000   6.630000   7530600.0   6.630000
#
# [3525 rows x 6 columns]

# %%
def fx(num):
    if num>20:
        return 'less'
    else:
        return 'more'

# %%
daat['Open'].apply(fx).value_counts()
# a = daat['Open'].apply(fx)
# a
# Out:
# Date
# 2007-01-03    less
# 2007-01-04    less
# 2007-01-05    less
# 2007-01-08    less
# 2007-01-09    less
#               ...
# 2020-12-24    more
# 2020-12-28    more
# 2020-12-29    more
# 2020-12-30    more
# 2020-12-31    more
# Name: Open, Length: 3525, dtype: object

# %%
daat['Open'].apply(fx).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
daat['Open'].apply(fx).value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
daat['Open'].apply(fx).value_counts().plot(kind='pie',legend=True)
# Out:
# <AxesSubplot:ylabel='Open'>

# %%
down = pd.read_csv('https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv?accessType=DOWNLOAD')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
down

# %%
down['Child\'s First Name'].to_frame()#convert series into df
# Out:
#       Child's First Name
# 0              GERALDINE
# 1                    GIA
# 2                 GIANNA
# 3                GISELLE
# 4                  GRACE
# ...                  ...
# 37532             Yousef
# 37533            Youssef
# 37534              Yusuf
# 37535            Zachary
# 37536                Zev
#
# [37537 rows x 1 columns]

# %%
down['Child\'s First Name'].tolist()
# Out:
# ['GERALDINE',
#  'GIA',
#  'GIANNA',
#  'GISELLE',
#  'GRACE',
#  'GUADALUPE',
#  'HAILEY',
#  'HALEY',
#  'HANNAH',
#  'HAYLEE',
#  'HAYLEY',
#  'HAZEL',
#  'HEAVEN',
#  'HEIDI',
#  'HEIDY',
#  'HELEN',
#  'IMANI',
#  'INGRID',
#  'IRENE',
#  'IRIS',
#  'ISABEL',
#  'ISABELA',
#  'ISABELLA',
#  'ISABELLE',
#  'ISIS',
#  'ITZEL',
#  'IZABELLA',
#  'JACQUELINE',
#  'JADA',
#  'JADE',
#  'JAELYNN',
#  'JAMIE',
#  'JANELLE',
#  'JASLENE',
#  'JASMIN',
#  'JASMINE',
#  'JAYDA',
#  'JAYLA',
#  'JAYLAH',
#  'JAYLEEN',
#  'JAYLENE',
#  'JAYLIN',
#  'JAYLYN',
#  'JAZLYN',
#  'JAZMIN',
#  'JAZMINE',
#  'JENNIFER',
#  'JESSICA',
#  'JIMENA',
#  'JOCELYN',
#  'JOHANNA',
#  'JOSELYN',
#  'JULIA',
#  'JULIANA',
#  'JULIANNA',
#  'JULIET',
#  'JULIETTE',
#  'JULISSA',
#  'KAELYN',
#  'KAILEY',
#  'KAILYN',
#  'KAITLYN',
#  'KAMILA',
#  'KAREN',
#  'KARLA',
#  'KATE',
#  'KATELYN',
#  'KATELYNN',
#  'KATHERINE',
#  'KATIE',
#  'KAYLA',
#  'KAYLEE',
#  'KAYLEEN',
#  'KAYLEIGH',
#  'KAYLIE',
# ...

# %%
down['Child\'s First Name'].to_dict()
# Out:
# {0: 'GERALDINE',
#  1: 'GIA',
#  2: 'GIANNA',
#  3: 'GISELLE',
#  4: 'GRACE',
#  5: 'GUADALUPE',
#  6: 'HAILEY',
#  7: 'HALEY',
#  8: 'HANNAH',
#  9: 'HAYLEE',
#  10: 'HAYLEY',
#  11: 'HAZEL',
#  12: 'HEAVEN',
#  13: 'HEIDI',
#  14: 'HEIDY',
#  15: 'HELEN',
#  16: 'IMANI',
#  17: 'INGRID',
#  18: 'IRENE',
#  19: 'IRIS',
#  20: 'ISABEL',
#  21: 'ISABELA',
#  22: 'ISABELLA',
#  23: 'ISABELLE',
#  24: 'ISIS',
#  25: 'ITZEL',
#  26: 'IZABELLA',
#  27: 'JACQUELINE',
#  28: 'JADA',
#  29: 'JADE',
#  30: 'JAELYNN',
#  31: 'JAMIE',
#  32: 'JANELLE',
#  33: 'JASLENE',
#  34: 'JASMIN',
#  35: 'JASMINE',
#  36: 'JAYDA',
#  37: 'JAYLA',
#  38: 'JAYLAH',
#  39: 'JAYLEEN',
#  40: 'JAYLENE',
#  41: 'JAYLIN',
#  42: 'JAYLYN',
#  43: 'JAZLYN',
#  44: 'JAZMIN',
#  45: 'JAZMINE',
#  46: 'JENNIFER',
#  47: 'JESSICA',
#  48: 'JIMENA',
#  49: 'JOCELYN',
#  50: 'JOHANNA',
#  51: 'JOSELYN',
#  52: 'JULIA',
#  53: 'JULIANA',
#  54: 'JULIANNA',
#  55: 'JULIET',
#  56: 'JULIETTE',
#  57: 'JULISSA',
# ...

# %%
", ".join(down['Child\'s First Name'].str.title().drop_duplicates().sort_values())
# Out:
# "Aahil, Aaliyah, Aarav, Aaron, Aarya, Aaryan, Aayan, Abby, Abdiel, Abdoul, Abdoulaye, Abdul, Abdullah, Abe, Abel, Abigail, Aboubacar, Abraham, Abrar, Abrielle, Abril, Ace, Ada, Adalynn, Adam, Adan, Addison, Adelaide, Adele, Adelina, Adeline, Adelyn, Aden, Adiel, Adina, Aditya, Adonis, Adrian, Adriana, Adrianna, Adriel, Adyan, Aharon, Ahmad, Ahmed, Ahnaf, Ahron, Ahuva, Aicha, Aidan, Aiden, Aileen, Aimee, Aisha, Aissata, Aissatou, Aitana, Aiza, Aizah, Akiva, Alaia, Alaina, Alan, Alana, Alani, Alanis, Alanna, Alayna, Alba, Albert, Alberto, Aldo, Aleah, Alec, Aleena, Alejandra, Alejandro, Aleksander, Aleksandra, Alessandra, Alessandro, Alessia, Alex, Alexa, Alexander, Alexandra, Alexandria, Alexia, Alexis, Alfred, Alfredo, Ali, Alia, Aliah, Alice, Alicia, Alijah, Alina, Alisa, Alisha, Alison, Alissa, Alisson, Aliyah, Aliza, Allan, Allen, Allison, Allyson, Alma, Alondra, Alonso, Alpha, Alston, Alter, Alvin, Alyson, Alyssa, Amadou, Amaia, Amalia, Amanda, Amani, Amar'E, Amara, Amare, Amari,
# ...

# %%
down.to_csv('NYC.csv',columns=['Year of Birth','Gender'],index=False,encoding='utf-8')#if you are not able to save encoding='utf-8'

# %%
downex= pd.read_csv('NYC.csv')

# %%
downex
# Out:
#        Year of Birth  Gender
# 0               2011  FEMALE
# 1               2011  FEMALE
# 2               2011  FEMALE
# 3               2011  FEMALE
# 4               2011  FEMALE
# ...              ...     ...
# 37532           2014    MALE
# 37533           2014    MALE
# 37534           2014    MALE
# 37535           2014    MALE
# 37536           2014    MALE
#
# [37537 rows x 2 columns]

# %%
#excel

# %%
import pandas as pd

# %%
ex = pd.read_excel("Data - Single Worksheet.xlsx")
ex
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
import pandas as pd

# %%
exx = pd.read_excel("Data - Multiple Worksheets.xlsx",sheet_name=[0,1]) 
# no shet name is provided pnadas will target first sheet
# none sheet_nmae will import everything
# [0,1] are sheet index it can be sheet name to excess this do exx[0] for 1st sheet
exx
# Out:
# {0:   First Name Last Name           City Gender
#  0    Brandon     James          Miami      M
#  1       Sean   Hawkins         Denver      M
#  2       Judy       Day    Los Angeles      F
#  3     Ashley      Ruiz  San Francisco      F
#  4  Stephanie     Gomez       Portland      F,
#  1:   First Name Last Name           City Gender
#  0     Parker     Power        Raleigh      F
#  1    Preston  Prescott   Philadelphia      F
#  2    Ronaldo   Donaldo         Bangor      M
#  3      Megan   Stiller  San Francisco      M
#  4     Bustin    Jieber         Austin      F}

# %%
type(exx)
exx[0]
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
#now to load 1st sheet
exx[1]
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
#exporting into excel

# %%
exn = pd.read_csv('https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv?accessType=DOWNLOAD')
exn
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 39467           2019  FEMALE  BLACK NON HISPANIC              Sanai     10
# 39468           2019  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 39469           2019  FEMALE  BLACK NON HISPANIC              Sevyn     10
# 39470           2019  FEMALE  BLACK NON HISPANIC             Zariah     10
# 39471           2019  FEMALE  BLACK NON HISPANIC              Zhuri     10
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# ...

# %%
girls = exn[exn['Gender']=='FEMALE']
boys = exn[exn['Gender']=='MALE']

# %%
#excel constructor
excelf = pd.ExcelWriter('babynames.xlsx')
girls.to_excel(excelf,sheet_name='Girls',index=False)
boys.to_excel(excelf,sheet_name='Boys',index=False,columns=['Year of Birth','Gender','Child\'s First Name'])

# %%
excelf.save()
