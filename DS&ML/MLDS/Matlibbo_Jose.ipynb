# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# # fx method

# %%
import numpy as np
x1 = np.arange(0,10,2)
fig, ax = plt.subplots(ncols=1,nrows=1, figsi)

# %%
plt.plot(x,y,'r-')
plt.xlabel('X lable')
plt.ylabel('Y lable')
plt.title('PLT')
# Out:
# Text(0.5, 1.0, 'PLT')

# %% [markdown]
# # multiple plot on same canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# # oops metthod

# %%
fig = plt.figure()

# %%
#left,bottom,width,hieght
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('xlabel')
axes.set_ylabel('xlabel')
axes.set_title('xlabel')
# Out:
# Text(0.5, 1.0, 'xlabel')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('large')

axes2.plot(y,x)
axes2.set_title('small')
# Out:
# Text(0.5, 1.0, 'small')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
#plt.tight_layout()
# for i in axes:
#     i.plot(x,y)
#axes is a list     
axes[0].plot(x,y)
axes[1].plot(y,x)

# %% [markdown]
# # Figure, Size and DPI

# %%
fig = plt.figure(figsize=(8,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig.savefig('joseM.png',dpi=200)

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,label='one')
axes.plot(y,x,label='two')
axes.legend(loc=5)#location
#axes.legend(loc=(0.1,0.1))

# %% [markdown]
# # customize

# %%
fig = plt.figure()
ax= fig.add_axes([0,0,1,1])
ax.plot(x,y,color='green',linewidth=3,alpha=0.5,linestyle=':',marker='o',markersize=10
       ,markerfacecolor='yellow',markeredgewidth=3,markeredgecolor='black')#lw & lswill also work,#aplha transparency
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)
