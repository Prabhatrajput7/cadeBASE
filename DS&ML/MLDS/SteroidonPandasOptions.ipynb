# ..   ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..
# 998  11  22  51  65  88  54  60  34  48  74  ...  96  33  12  90  87  34  85
# 999   4  98  46  93  46  69  72  27  61  65  ...  93  18  46  40  48  13  31
#
#      47  48  49
# 0    62   9  28
# 1    19  32  18
# ..   ..  ..  ..
# 998  99  79  36
# 999  41  27  88
#
# [1000 rows x 50 columns]

# %%
pd.options.display.max_columns = 4
df
# Out:
#      0   1   ...  48  49
# 0     7  58  ...   9  28
# 1    32  67  ...  32  18
# ..   ..  ..  ...  ..  ..
# 998  11  22  ...  79  36
# 999   4  98  ...  27  88
#
# [1000 rows x 50 columns]

# %%
pd.get_option('max_rows')
# Out:
# 4

# %%
pd.set_option('max_rows',6)

# %%
df
# Out:
#      0   1   ...  48  49
# 0     7  58  ...   9  28
# 1    32  67  ...  32  18
# 2     6  70  ...  86   6
# ..   ..  ..  ...  ..  ..
# 997  33  60  ...  98  73
# 998  11  22  ...  79  36
# 999   4  98  ...  27  88
#
# [1000 rows x 50 columns]

# %%
pd.reset_option('max_columns')

# %%
pd.get_option('max_columns')
# Out:
# 20

# %%
pd.describe_option('max_columns')
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 20]

# %%
df2 = pd.DataFrame(np.random.rand(5,5))
df2
# Out:
#           0         1         2         3         4
# 0  0.976391  0.147711  0.761458  0.642429  0.615748
# 1  0.387110  0.387639  0.769046  0.449973  0.330828
# 2  0.472055  0.999739  0.747125  0.387727  0.191376
# 3  0.813794  0.885588  0.850433  0.253494  0.401409
# 4  0.774931  0.758081  0.987458  0.071173  0.205849

# %%
pd.get_option('precision')
# Out:
# 6

# %%
pd.set_option('precision',2)
df2
# Out:
#       0     1     2     3     4
# 0  0.98  0.15  0.76  0.64  0.62
# 1  0.39  0.39  0.77  0.45  0.33
# 2  0.47  1.00  0.75  0.39  0.19
# 3  0.81  0.89  0.85  0.25  0.40
# 4  0.77  0.76  0.99  0.07  0.21

# %%
pd.reset_option('precision')
df2
# Out:
#           0         1         2         3         4
# 0  0.976391  0.147711  0.761458  0.642429  0.615748
# 1  0.387110  0.387639  0.769046  0.449973  0.330828
# 2  0.472055  0.999739  0.747125  0.387727  0.191376
# 3  0.813794  0.885588  0.850433  0.253494  0.401409
# 4  0.774931  0.758081  0.987458  0.071173  0.205849

# %%
import pandas as pd

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
"""
pd.options.display.max_rows
pd.get_option/set/reset
max_rows/max_columns/precision
"""
# Out:
# '\npd.options.display.max_rows\n'
