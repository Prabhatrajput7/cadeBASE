# %%
lst = [{'random1': 2,'random2':10},{'random1': 2,'random2':8},{'random1': 6,'random2':6},{'random1': 8,'random2':4},{'random1': 10,'random2':2},{'random1': 1,'random2':10}]
lst
# Out:
# [{'random1': 2, 'random2': 10},
#  {'random1': 2, 'random2': 8},
#  {'random1': 6, 'random2': 6},
#  {'random1': 8, 'random2': 4},
#  {'random1': 10, 'random2': 2},
#  {'random1': 1, 'random2': 10}]

# %%
import pandas as pd
newdf = pd.DataFrame(lst,index=['one','two','three','four','five','six'])
newdf.drop_duplicates(['random1'])
# Out:
#        random1  random2
# one          2       10
# three        6        6
# four         8        4
# five        10        2
# six          1       10

# %%
newdf.sum(axis=1)
# Out:
# one      12
# two      12
# three    12
# four     12
# five     12
# six      11
# dtype: int64

# %%
newdf.drop('six',axis=0)
# Out:
#        random1  random2
# one          2       10
# two          4        8
# three        6        6
# four         8        4
# five        10        2

# %%
newdf.loc['five'].sum()
# Out:
# 12

# %%
import pandas as pd

# %%
ser = pd.read_csv('pokemon.csv', usecols=['Pokemon'], squeeze=True) #converting a DF to Series
ser
# Out:
# C:\Users\Prabh\AppData\Local\Temp\ipykernel_18668\1928793251.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   ser = pd.read_csv('pokemon.csv', usecols=['Pokemon'], squeeze=True) #converting a DF to Series
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
ser.value_counts()
# Out:
# Bulbasaur    1
# Gallade      1
# Dusknoir     1
# Froslass     1
# Rotom        1
#             ..
# Raikou       1
# Entei        1
# Suicune      1
# Larvitar     1
# Volcanion    1
# Name: Pokemon, Length: 721, dtype: int64

# %%
fruit = ['Apple','banana']
vege = ['palak','panner']
nut = pd.Series(fruit,vege)
# first argument is always data in series

# %%
nut
# Out:
# palak      Apple
# panner    banana
# dtype: object

# %%
nut.name = 'nutty'

# %%
nut
# Out:
# palak      Apple
# panner    banana
# Name: nutty, dtype: object

# %%
ser
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
ser.sort_index().head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
ser.sort_index(ascending=False,inplace=True)
ser
# Out:
# 720     Volcanion
# 719         Hoopa
# 718       Diancie
# 717       Zygarde
# 716       Yveltal
#           ...
# 4      Charmeleon
# 3      Charmander
# 2        Venusaur
# 1         Ivysaur
# 0       Bulbasaur
# Name: Pokemon, Length: 721, dtype: object

# %% [markdown]
# # Permanent Modifying Series

# %%
#inplace

# %%
ser
# Out:
# 720     Volcanion
# 719         Hoopa
# 718       Diancie
# 717       Zygarde
# 716       Yveltal
#           ...
# 4      Charmeleon
# 3      Charmander
# 2        Venusaur
# 1         Ivysaur
# 0       Bulbasaur
# Name: Pokemon, Length: 721, dtype: object

# %%
ser.sort_index(ascending=True,inplace=True)
ser
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
ser
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
"Bulbasaur" in ser
# Out:
# False

# %%
"Bulbasaur" in ser.values
# Out:
# True

# %%
ser[[100,200,300]]
# Out:
# 100    Electrode
# 200        Unown
# 300     Delcatty
# Name: Pokemon, dtype: object

# %%
ser[-30:]
# Out:
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# 710     Gourgeist
# 711      Bergmite
# 712       Avalugg
# 713        Noibat
# 714       Noivern
# 715       Xerneas
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, dtype: object

# %%
ser.values
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon',
#        'Charizard', 'Squirtle', 'Wartortle', 'Blastoise', 'Caterpie',
#        'Metapod', 'Butterfree', 'Weedle', 'Kakuna', 'Beedrill', 'Pidgey',
#        'Pidgeotto', 'Pidgeot', 'Rattata', 'Raticate', 'Spearow', 'Fearow',
#        'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew', 'Sandslash',
#        'Nidoran', 'Nidorina', 'Nidoqueen', 'Nidoran♂', 'Nidorino',
#        'Nidoking', 'Clefairy', 'Clefable', 'Vulpix', 'Ninetales',
#        'Jigglypuff', 'Wigglytuff', 'Zubat', 'Golbat', 'Oddish', 'Gloom',
#        'Vileplume', 'Paras', 'Parasect', 'Venonat', 'Venomoth', 'Diglett',
#        'Dugtrio', 'Meowth', 'Persian', 'Psyduck', 'Golduck', 'Mankey',
#        'Primeape', 'Growlithe', 'Arcanine', 'Poliwag', 'Poliwhirl',
#        'Poliwrath', 'Abra', 'Kadabra', 'Alakazam', 'Machop', 'Machoke',
#        'Machamp', 'Bellsprout', 'Weepinbell', 'Victreebel', 'Tentacool',
# ...

# %%
len(ser)
# Out:
# 721

# %%
ser2 =  pd.read_csv('pokemon.csv', index_col='Pokemon',squeeze=True)
ser2
# Out:
# C:\Users\Prabh\AppData\Local\Temp\ipykernel_19588\3716618648.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   ser2 =  pd.read_csv('pokemon.csv', index_col='Pokemon',squeeze=True)
# Pokemon
# Bulbasaur       Grass
# Ivysaur         Grass
# Venusaur        Grass
# Charmander       Fire
# Charmeleon       Fire
#                ...
# Yveltal          Dark
# Zygarde        Dragon
# Diancie          Rock
# Hoopa         Psychic
# Volcanion        Fire
# Name: Type, Length: 721, dtype: object

# %%
ser2['Bulbasaur']
# Out:
# 'Grass'

# %%
ser2[0]
# Out:
# 'Grass'

# %%
ser2.reindex(index=['Pikachu','digimon'])
# Out:
# Pokemon
# Pikachu    Electric
# digimon         NaN
# Name: Type, dtype: object

# %% [markdown]
# # Get

# %%
ser2
# Out:
# Pokemon
# Bulbasaur       Grass
# Ivysaur         Grass
# Venusaur        Grass
# Charmander       Fire
# Charmeleon       Fire
#                ...
# Yveltal          Dark
# Zygarde        Dragon
# Diancie          Rock
# Hoopa         Psychic
# Volcanion        Fire
# Name: Type, Length: 721, dtype: object

# %%
ser2.sort_index(inplace=True)

# %%
ser2
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Psychic
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
#               ...
# Zoroark         Dark
# Zorua           Dark
# Zubat         Poison
# Zweilous        Dark
# Zygarde       Dragon
# Name: Type, Length: 721, dtype: object

# %%
ser2.get(0)
# Out:
# 'Grass'

# %%
ser2.get(['Zygarde'])
# Out:
# Pokemon
# Zygarde    Dragon
# Name: Type, dtype: object

# %%
ser2.get(key = ['Zygarde','Zubat'], default='Not a poke')
# Out:
# Pokemon
# Zygarde    Dragon
# Zubat      Poison
# Name: Type, dtype: object

# %%
ser2.get(key = 'digi', default='Not a poke')
# Out:
# 'Not a poke'

# %%
ser2.get([0,5])
# Out:
# Pokemon
# Abomasnow     Grass
# Aerodactyl     Rock
# Name: Type, dtype: object

# %%
ser2.get([0,5,1000])#no result as there is no 1000 row in sheet and get default return type is null

# %%
# difference b/w count and len count dont count Nan value

# %%
ser.idxmin
# Out:
# <bound method Series.idxmin of 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object>

# %%
#idzmin()and idxmax return min and max index that is storing value

# %%
goo = pd.read_csv('google_stock_price.csv',squeeze=True)
goo
# Out:
# C:\Users\Prabh\AppData\Local\Temp\ipykernel_19588\3777572274.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   goo = pd.read_csv('google_stock_price.csv',squeeze=True)
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %%
goo.idxmax()
# Out:
# 3011

# %%
goo[goo.idxmax()]
# Out:
# 782.22

# %%
len(ser2.value_counts())
# Out:
# 18

# %%
len(ser2.values)
# Out:
# 721

# %%
ser2.value_counts()
# Out:
# Water       105
# Normal       93
# Grass        66
# Bug          63
# Fire         47
# Psychic      47
# Rock         41
# Electric     36
# Ground       30
# Poison       28
# Dark         28
# Fighting     25
# Dragon       24
# Ice          23
# Ghost        23
# Steel        22
# Fairy        17
# Flying        3
# Name: Type, dtype: int64

# %%
ser2.value_counts().sum()
# Out:
# 721

# %%
goo.head(5)
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64

# %%
def fx(num):
    if num<100:
        return 'OK'
    else:
        return 'KO'

# %%
goo.apply(fx)
# Out:
# 0       OK
# 1       OK
# 2       OK
# 3       OK
# 4       OK
#         ..
# 3007    KO
# 3008    KO
# 3009    KO
# 3010    KO
# 3011    KO
# Name: Stock Price, Length: 3012, dtype: object

# %%
goo.apply(lambda sp:sp*sp)
# Out:
# 0         2512.0144
# 1         2926.8100
# 2         2986.6225
# 3         2743.6644
# 4         2803.7025
#            ...
# 3007    597343.4944
# 3008    594548.9449
# 3009    597807.3124
# 3010    595381.9921
# 3011    611868.1284
# Name: Stock Price, Length: 3012, dtype: float64

# %%
ser
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
ser2
# Out:
# Pokemon
# Bulbasaur       Grass
# Ivysaur         Grass
# Venusaur        Grass
# Charmander       Fire
# Charmeleon       Fire
#                ...
# Yveltal          Dark
# Zygarde        Dragon
# Diancie          Rock
# Hoopa         Psychic
# Volcanion        Fire
# Name: Type, Length: 721, dtype: object

# %%
ser.map(ser2)
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3         Fire
# 4         Fire
#         ...
# 716       Dark
# 717     Dragon
# 718       Rock
# 719    Psychic
# 720       Fire
# Name: Pokemon, Length: 721, dtype: object

# %% [markdown]
# # DF

# %%
nba = pd.read_csv('nba.csv')
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
rev = pd.read_csv('revenue.csv')
rev
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/16       985          122    499
# 1   1/2/16       738          788    534
# 2   1/3/16        14           20    933
# 3   1/4/16       730          904    885
# 4   1/5/16       114           71    253
# 5   1/6/16       936          502    497
# 6   1/7/16       123          996    115
# 7   1/8/16       935          492    886
# 8   1/9/16       846          954    823
# 9  1/10/16        54          285    216

# %%
import pandas as pd

# %%
srev = pd.read_csv('revenue.csv', index_col='Date')
srev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
srev.sum('New York',axis=1)
srev.drop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 srev.sum('New York',axis=1)
#
# TypeError: NDFrame._add_numeric_operations.<locals>.sum() got multiple values for argument 'axis'

# %%
type(srev)
# Out:
# pandas.core.frame.DataFrame

# %%
srev.index
# Out:
# Index(['1/1/16', '1/2/16', '1/3/16', '1/4/16', '1/5/16', '1/6/16', '1/7/16',
#        '1/8/16', '1/9/16', '1/10/16'],
#       dtype='object', name='Date')

# %%
srev.sum(axis=0)
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
srev.sum(axis=1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba[['Name','Team','Age']]
# Out:
#               Name            Team   Age
# 0    Avery Bradley  Boston Celtics  25.0
# 1      Jae Crowder  Boston Celtics  25.0
# 2     John Holland  Boston Celtics  27.0
# 3      R.J. Hunter  Boston Celtics  22.0
# 4    Jonas Jerebko  Boston Celtics  29.0
# ..             ...             ...   ...
# 453   Shelvin Mack       Utah Jazz  26.0
# 454      Raul Neto       Utah Jazz  24.0
# 455   Tibor Pleiss       Utah Jazz  26.0
# 456    Jeff Withey       Utah Jazz  26.0
# 457            NaN             NaN   NaN
#
# [458 rows x 3 columns]

# %%
lst = [i*i for i in range(458)]
nba['NewC'] = lst

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary    NewC
# 0                Texas  7730337.0       0
# ...

# %%
nba.drop('NewC',axis=1,inplace=True)

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#insert col no need to use inplace

# %%
nba.insert(3, column='Game',value='Football')
nba
# Out:
#               Name            Team  Number      Game Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Football       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Football       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Football       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Football       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Football       PF  29.0   6-10
# ..             ...             ...     ...       ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0  Football       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Football       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Football        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Football        C  26.0    7-0
# 457            NaN             NaN     NaN  Football      NaN   NaN    NaN
#
#      Weight            College     Salary
# ...

# %%
nba['Age']+5
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
#        ...
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba['LBS'] = nba['Weight'] * 2.1

# %%
nba
# Out:
#               Name            Team  Number      Game Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Football       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Football       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Football       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Football       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Football       PF  29.0   6-10
# ..             ...             ...     ...       ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0  Football       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Football       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Football        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Football        C  26.0    7-0
# 457            NaN             NaN     NaN  Football      NaN   NaN    NaN
#
#      Weight            College     Salary    LBS
# ...

# %%
nba.dropna()
#nba.dropna(axis=1) drop col with nah value
#nba.dropna(how='all') all rows are NaN
#nba.dropna(subset=['salary','LBS']) to drop NaN from a particular cols
nba
# Out:
#               Name            Team  Number      Game Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Football       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Football       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Football       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Football       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Football       PF  29.0   6-10
# ..             ...             ...     ...       ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0  Football       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Football       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Football        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Football        C  26.0    7-0
# 457            NaN             NaN     NaN  Football      NaN   NaN    NaN
#
#      Weight            College     Salary    LBS
# ...

# %%
nba
# Out:
#               Name            Team  Number      Game Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Football       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Football       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Football       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Football       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Football       PF  29.0   6-10
# ..             ...             ...     ...       ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0  Football       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Football       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Football        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Football        C  26.0    7-0
# 457            NaN             NaN     NaN  Football      NaN   NaN    NaN
#
#      Weight            College     Salary    LBS
# ...

# %%
nba2 = pd.read_csv('nba.csv')
nba2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba2.rename(columns={'Number':'Nums'},inplace=True)
nba2
# Out:
#               Name            Team  Nums Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics   0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics  99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics  30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics  28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics   8.0       PF  29.0   6-10   231.0
# ..             ...             ...   ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz   8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz  25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz  21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz  24.0        C  26.0    7-0   231.0
# 457            NaN             NaN   NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# ...

# %%
nba2['Salary'].fillna(0,inplace=False)
nba2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba2.dropna(inplace=True)

# %%
nba2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
nba2['Salary'] =nba2['Salary'].astype('int')

# %%
nba2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College   Salary
# 0            Texas  7730337
# 1        Marquette  6796117
# ...

# %%
nba2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    object
#  4   Age       364 non-null    float64
#  5   Height    364 non-null    object
#  6   Weight    364 non-null    float64
#  7   College   364 non-null    object
#  8   Salary    364 non-null    int32
# dtypes: float64(3), int32(1), object(5)
# memory usage: 27.0+ KB

# %%
#nba2.sort_values(na_position='first'/'last') #show  df all nan at first or last

# %%
nba2.sort_values('Name',ascending=False)
# Out:
#                 Name                    Team  Nums Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks  27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies  50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves   8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies  14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets  21.0       SF  29.0    6-8
# ..               ...                     ...   ...      ...   ...    ...
# 404    Adreian Payne  Minnesota Timberwolves  33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets   9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic   0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls   0.0       PG  31.0    6-0
# 457              NaN                     NaN   NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# 237   275.0             NaN   5200000.0
# ...

# %%
nba2.sort_values(['Team','Name'],ascending=[True,False])
# Out:
#                  Name                Team  Number Position   Age Height  \
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# 319        Mike Scott       Atlanta Hawks    32.0       PF  27.0    6-8
# 316      Mike Muscala       Atlanta Hawks    31.0       PF  24.0   6-11
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0    6-5
# ..                ...                 ...     ...      ...   ...    ...
# 374        JJ Hickson  Washington Wizards    21.0        C  27.0    6-9
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# 372       Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
#
#      Weight               College    Salary
# 310   205.0              Michigan   1304520
# ...

# %%
nba2['Name'] = nba['Name']

# %%
nba2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College   Salary
# 0            Texas  7730337
# 1        Marquette  6796117
# ...

# %%
nba2['Salary'].fillna(0,inplace = True)

# %%
nba2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College   Salary  Ranking
# 0            Texas  7730337     74.0
# ...

# %%
nba3 = pd.read_csv('nba.csv')
nba3
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba3.dropna(inplace=True)

# %%
nba3['Salary'] = nba3['Salary'].astype('int')

# %%
nba3
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College   Salary
# 0            Texas  7730337
# 1        Marquette  6796117
# ...

# %%
nba3['Ranking'] = nba3['Salary'].rank(ascending=False).astype('int')
#rank will put highest salary at last so using ascending = False

# %%
nba3
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College   Salary  Ranking
# 0            Texas  7730337       74
# ...

# %%
nba3.sort_values('Salary',ascending=False)
# Out:
#                 Name                   Team  Number Position   Age Height  \
# 33   Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
# 339       Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 100       Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 414     Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164     Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# ..               ...                    ...     ...      ...   ...    ...
# 92        Jeff Ayres   Los Angeles Clippers    19.0       PF  29.0    6-9
# 175     Jordan McRae    Cleveland Cavaliers    12.0       SG  25.0    6-5
# 135    Alan Williams           Phoenix Suns    15.0        C  23.0    6-8
# 291  Orlando Johnson   New Orleans Pelicans     0.0       SG  27.0    6-5
# 130     Phil Pressey           Phoenix Suns    25.0       PG  25.0   5-11
#
#      Weight           College    Salary  Ranking
# ...

# %% [markdown]
# # Filtering

# %%
emp = pd.read_csv('employees.csv')
emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp['Start Date'] = pd.to_datetime(emp['Start Date'])
emp['Last Login Time'] = pd.to_datetime(emp['Last Login Time'])
emp['Senior Management'] = emp['Senior Management'].astype('bool')
emp['Gender'] = emp['Gender'].astype('category')
emp
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-12-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-12-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2021-12-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-12-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-12-31 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2021-12-31 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2021-12-31 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2021-12-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2021-12-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2021-12-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
#changing type on import

# %%
emp1 = pd.read_csv('employees.csv',parse_dates=['Start Date','Last Login Time'])
emp1['Senior Management'] = emp1['Senior Management'].astype('bool')
emp1['Gender'] = emp1['Gender'].astype('category')
emp1
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-04-13 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-04-13 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-04-13 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-04-13 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-04-13 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-04-13 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-04-13 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-04-13 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-04-13 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-04-13 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp1['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
emp1[emp1['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-12-31 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2021-12-31 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2021-12-31 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-12-31 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-12-31 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2021-12-31 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2021-12-31 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2021-12-31 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2021-12-31 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2021-12-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp1[(emp1['Gender'] == 'Male') & (emp1['Salary']>90000)] #and
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-12-31 12:42:00   97308    6.945
# 3        Jerry   Male 2005-03-04 2021-12-31 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-12-31 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-12-31 01:35:00  115163   10.125
# 12     Brandon   Male 1980-12-01 2021-12-31 01:08:00  112807   17.492
# ..         ...    ...        ...                 ...     ...      ...
# 983       John   Male 1982-12-23 2021-12-31 22:35:00  146907   11.738
# 992    Anthony   Male 2011-10-16 2021-12-31 08:35:00  112769   11.625
# 994     George   Male 2013-06-21 2021-12-31 17:47:00   98874    4.479
# 997    Russell   Male 2013-05-20 2021-12-31 12:39:00   96914    1.421
# 999     Albert   Male 2012-05-15 2021-12-31 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 3                 True          Finance
# ...

# %%
emp1[(emp1['Gender'] == 'Male') | (emp1['Salary']>90000)] #or
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-12-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-12-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2021-12-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-12-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-12-31 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2021-12-31 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2021-12-31 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2021-12-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2021-12-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2021-12-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
m  = emp1['Gender'] == 'Male'
s = emp1['Salary']>90000
p = emp1['Team'] == 'Product'
emp1[m & s | p]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-12-31 12:42:00   97308    6.945
# 3        Jerry    Male 2005-03-04 2021-12-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-12-31 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2021-12-31 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-12-31 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 983       John    Male 1982-12-23 2021-12-31 22:35:00  146907   11.738
# 992    Anthony    Male 2011-10-16 2021-12-31 08:35:00  112769   11.625
# 994     George    Male 2013-06-21 2021-12-31 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2021-12-31 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2021-12-31 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
#isin method

# %%
option = ['Legal','Sales','Product']
emp1[emp1['Team'].isin(option)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2021-12-31 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-12-31 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2021-12-31 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2021-12-31 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2021-12-31 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2021-12-31 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2021-12-31 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2021-12-31 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2021-12-31 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2021-12-31 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %%
#isnull(check is value null or not if yes then true) and not null(check value should not be null if there is value so  true)

# %%
emp1['Team'].isnull()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
emp1[emp1['Team'].isnull()] #is null check for null values only
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2022-03-29 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2022-03-29 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2022-03-29 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2022-03-29 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2022-03-29 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2022-03-29 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2022-03-29 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2022-03-29 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2022-03-29 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2022-03-29 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2022-03-29 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2022-03-29 06:06:00   66067   10.957
# ...

# %%
emp1['Gender'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
emp1[emp1['Gender'].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-29 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-29 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-03-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-29 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-29 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-03-29 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-03-29 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-03-29 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-03-29 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-03-29 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
#between

# %%
emp1[emp1['Salary'].between(80000,100000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-12-31 12:42:00   97308    6.945
# 8       Angela  Female 2005-11-22 2021-12-31 06:29:00   95570   18.523
# 16      Jeremy    Male 2010-09-21 2021-12-31 05:56:00   90370    7.369
# 19       Donna  Female 2010-07-22 2021-12-31 03:48:00   81014    1.894
# 22      Joshua     NaN 2012-03-08 2021-12-31 01:58:00   90816   18.816
# ..         ...     ...        ...                 ...     ...      ...
# 982       Rose  Female 1982-04-06 2021-12-31 10:43:00   91411    8.639
# 985    Stephen     NaN 1983-07-10 2021-12-31 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2021-12-31 07:04:00   82871   17.999
# 994     George    Male 2013-06-21 2021-12-31 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2021-12-31 12:39:00   96914    1.421
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
emp1[emp1['Last Login Time'].between("08:30 AM","10:00 AM")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2021-12-31 09:01:00   63241   15.132
# 33        Jean  Female 1993-12-18 2021-12-31 09:07:00  119082   16.180
# 54        Sara  Female 2007-08-15 2021-12-31 09:23:00   83677    8.999
# 59       Irene  Female 1997-05-07 2021-12-31 09:32:00   66851   11.279
# 85      Jeremy    Male 2008-02-01 2021-12-31 08:50:00  100238    3.887
# 96     Cynthia  Female 1994-03-21 2021-12-31 08:34:00  142321    1.737
# 121   Kathleen     NaN 2016-05-09 2021-12-31 08:55:00  119735   18.740
# 157        NaN  Female 2005-07-27 2021-12-31 08:32:00   79536   14.443
# 161    Marilyn     NaN 1999-08-22 2021-12-31 09:09:00  103386   11.451
# 204     Willie    Male 2006-06-06 2021-12-31 09:45:00   55281    4.935
# 212       Lisa  Female 2009-11-02 2021-12-31 09:42:00  115387    1.821
# 259      Henry    Male 1995-02-06 2021-12-31 08:34:00   89258   15.585
# ...

# %%
#duplicates
emp1.sort_values('First Name',inplace=True)
emp1
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2021-12-31 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2021-12-31 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2021-12-31 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2021-12-31 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2021-12-31 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2021-12-31 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2021-12-31 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2021-12-31 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2021-12-31 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2021-12-31 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
emp1['First Name'].duplicated()#keep default keep is first
#aaron is 4 times the first is not dup as pandas is seeing it first time
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
emp1['First Name'].duplicated(keep='last')
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
emp1['First Name'].duplicated(keep=False) # this will mark all dup as True
# Out:
# 101    True
# 327    True
# 440    True
# 937    True
# 137    True
#        ...
# 902    True
# 925    True
# 946    True
# 947    True
# 951    True
# Name: First Name, Length: 1000, dtype: bool

# %%
~emp1['First Name'].duplicated(keep=False) # this will mark all dup as False
# Out:
# 101    False
# 327    False
# 440    False
# 937    False
# 137    False
#        ...
# 902    False
# 925    False
# 946    False
# 947    False
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
emp1[~emp1['First Name'].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2021-12-31 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2021-12-31 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2021-12-31 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2021-12-31 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2021-12-31 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2021-12-31 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2021-12-31 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2021-12-31 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2021-12-31 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %%
emp1.drop_duplicates(subset=['First Name'],keep = 'first',inplace=True)
emp1
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2021-12-31 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2021-12-31 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2021-12-31 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2021-12-31 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2021-12-31 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2021-12-31 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2021-12-31 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2021-12-31 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2021-12-31 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2021-12-31 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
#unique

# %%
emp1['Gender'].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
#nunique

# %%
emp1
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-04-13 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-04-13 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-04-13 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-04-13 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-04-13 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-04-13 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-04-13 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-04-13 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-04-13 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-04-13 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp1.dropna(inplace=True)
emp1.sort_values('First Name',inplace=True)

# %%
emp1
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 440      Aaron   Male 1990-07-22 2022-04-13 14:53:00   52119   11.343
# 327      Aaron   Male 1994-01-29 2022-04-13 18:48:00   58755    5.097
# 101      Aaron   Male 2012-02-17 2022-04-13 10:20:00   61602   11.849
# 137       Adam   Male 2011-05-21 2022-04-13 01:45:00   95327   15.120
# 538       Adam   Male 2010-10-08 2022-04-13 21:53:00   45181    3.491
# ..         ...    ...        ...                 ...     ...      ...
# 204     Willie   Male 2006-06-06 2022-04-13 09:45:00   55281    4.935
# 450     Willie   Male 2009-08-22 2022-04-13 13:03:00   55038   19.691
# 112     Willie   Male 2003-11-27 2022-04-13 06:21:00   64363    4.023
# 652     Willie   Male 2009-12-05 2022-04-13 05:39:00  141932    1.017
# 175     Willie   Male 1998-02-17 2022-04-13 20:20:00  146651    1.451
#
#      Senior Management             Team
# 440               True  Client Services
# 327               True        Marketing
# ...

# %%
# emp1.drop_duplicates(subset=['First Name'],keep='first')
emp1['First Name'].drop_duplicates(keep='first')
# Out:
# 440      Aaron
# 137       Adam
# 610       Alan
# 999     Albert
# 970      Alice
#         ...
# 655     Walter
# 433      Wanda
# 177      Wayne
# 127    William
# 204     Willie
# Name: First Name, Length: 199, dtype: object

# %%
emp1['Gender'].nunique()#not count NaN as dropna set to True by default
# Out:
# 2

# %%
emp1['Gender'].value_counts()
# Out:
# Female    431
# Male      424
# Name: Gender, dtype: int64

# %%
emp1['Gender'].nunique(dropna=False)
# Out:
# 3

# %%
bond = pd.read_csv('jamesbond.csv')
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
#bond = pd.read_csv('jamesbond.csv',index_col='Film')#permanet
bond2 = pd.read_csv('jamesbond.csv')
bond2
bond2.set_index(keys='Film',inplace=True)
bond2
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
#bond.reset_index(drop=True)
#by default drop is false is its True its override the previous index
bond2.reset_index(drop=False)
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond2
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
# if you want to change index now by set_index then the old one will get out of memory and reset index provide this

# %%
bond2.reset_index(inplace=True)# this will overwrite the film col to defaiult col i.e 0,1,2,3

# %%
bond2.set_index('Year',inplace=True)# if 2 do it 2 times it will overwrite the pervious oone

# %%
bond2
# Out:
#                                  Film           Actor            Director  \
# Year
# 1962                           Dr. No    Sean Connery       Terence Young
# 1963            From Russia with Love    Sean Connery       Terence Young
# 1964                       Goldfinger    Sean Connery        Guy Hamilton
# 1965                      Thunderball    Sean Connery       Terence Young
# 1967                    Casino Royale     David Niven          Ken Hughes
# 1967              You Only Live Twice    Sean Connery       Lewis Gilbert
# 1969  On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# 1971             Diamonds Are Forever    Sean Connery        Guy Hamilton
# 1973                 Live and Let Die     Roger Moore        Guy Hamilton
# 1974      The Man with the Golden Gun     Roger Moore        Guy Hamilton
# 1977             The Spy Who Loved Me     Roger Moore       Lewis Gilbert
# 1979                        Moonraker     Roger Moore       Lewis Gilbert
# ...

# %%
bond3 = pd.read_csv('jamesbond.csv', index_col='Film')
bond3.sort_index(inplace = True)

# %%
bond3
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond3.loc['Skyfall']
# Out:
# Year                         2012
# Actor                Daniel Craig
# Director               Sam Mendes
# Box Office                  943.5
# Budget                      170.2
# Bond Actor Salary            14.5
# Name: Skyfall, dtype: object

# %%
bond3.iloc[4]
# Out:
# Year                           2002
# Actor                Pierce Brosnan
# Director               Lee Tamahori
# Box Office                    465.4
# Budget                        154.2
# Bond Actor Salary              17.9
# Name: Die Another Day, dtype: object

# %%
bond3.loc[['Skyfall']]
# Out:
#          Year         Actor    Director  Box Office  Budget  Bond Actor Salary
# Film
# Skyfall  2012  Daniel Craig  Sam Mendes       943.5   170.2               14.5

# %%
bond3.iloc[[4]]
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9

# %%
bond3.iloc[[4,100]] #100 not exist error out
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\MLDS\env\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    1529         try:
# -> 1530             return self.obj._take_with_is_copy(key, axis=axis)
#    1531         except IndexError as err:
#
# ~\MLDS\env\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3627         """
# -> 3628         result = self.take(indices=indices, axis=axis)
#    3629         # Maybe set copy if we didn't actually change the index.
#
# ~\MLDS\env\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3614
# -> 3615         new_data = self._mgr.take(
#    3616             indices, axis=self._get_block_manager_axis(axis), verify=True
#
# ~\MLDS\env\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify)
# ...

# %%
bond3
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond3.loc['A View to a Kill','Director']
# Out:
# 'John Glen'

# %%
bond3.loc[['A View to a Kill','Spectre'],['Director']]
# Out:
#                     Director
# Film
# A View to a Kill   John Glen
# Spectre           Sam Mendes

# %%
bond3.loc[['A View to a Kill','Spectre'],:'Director']
# Out:
#                   Year         Actor    Director
# Film
# A View to a Kill  1985   Roger Moore   John Glen
# Spectre           2015  Daniel Craig  Sam Mendes

# %%
bond3.iloc[0,:2]
# Out:
# Year            1985
# Actor    Roger Moore
# Name: A View to a Kill, dtype: object

# %%
#loc and iloc slicing is different

# %%
#changing data in csv

# %%
bond3.loc['A View to a Kill','Director'] = 'Bunnu'

# %%
bond3.loc['A View to a Kill','Director']
# Out:
# 'Bunnu'

# %%
#Roger Moore
bond3.loc[bond3['Actor'] == 'Daniel Craig','Actor'] = 'DC'

# %%
bond3
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006              DC     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond3.rename(mapper={'Thunderball':'Thunderhead','Skyfall':'NightFall'})
# Out:
#                                   Year           Actor            Director  \
# Film
# A View to a Kill                 bunnu           bunnu               bunnu
# Casino Royale                     2006    Daniel Craig     Martin Campbell
# Casino Royale                     1967     David Niven          Ken Hughes
# Diamonds Are Forever              1971    Sean Connery        Guy Hamilton
# Die Another Day                   2002  Pierce Brosnan        Lee Tamahori
# Dr. No                            1962    Sean Connery       Terence Young
# For Your Eyes Only               bunnu           bunnu               bunnu
# From Russia with Love             1963    Sean Connery       Terence Young
# GoldenEye                         1995  Pierce Brosnan     Martin Campbell
# Goldfinger                        1964    Sean Connery        Guy Hamilton
# Licence to Kill                   1989  Timothy Dalton           John Glen
# ...

# %%
bond3.rename(mapper={'Thunderball':'Thunderhead','Skyfall':'NightFall'},axis = 0) #same thing man
bond3.rename(mapper={'Thunderball':'Thunderhead','Skyfall':'NightFall'},axis = 'rows')
bond3.rename(mapper={'Thunderball':'Thunderhead','Skyfall':'NightFall'},axis = 'index')
bond3.rename(index={'Thunderball':'Thunderhead','Skyfall':'NightFall'})
# Out:
#                                   Year           Actor            Director  \
# Film
# A View to a Kill                 bunnu           bunnu               bunnu
# Casino Royale                     2006    Daniel Craig     Martin Campbell
# Casino Royale                     1967     David Niven          Ken Hughes
# Diamonds Are Forever              1971    Sean Connery        Guy Hamilton
# Die Another Day                   2002  Pierce Brosnan        Lee Tamahori
# Dr. No                            1962    Sean Connery       Terence Young
# For Your Eyes Only               bunnu           bunnu               bunnu
# From Russia with Love             1963    Sean Connery       Terence Young
# GoldenEye                         1995  Pierce Brosnan     Martin Campbell
# Goldfinger                        1964    Sean Connery        Guy Hamilton
# Licence to Kill                   1989  Timothy Dalton           John Glen
# ...

# %%
#bond3.columns = [#provide a list here of same no of cols and it will rename cols]

# %%
bond3
# Out:
#                                   Year           Actor            Director  \
# Film
# A View to a Kill                 bunnu           bunnu               bunnu
# Casino Royale                     2006    Daniel Craig     Martin Campbell
# Casino Royale                     1967     David Niven          Ken Hughes
# Diamonds Are Forever              1971    Sean Connery        Guy Hamilton
# Die Another Day                   2002  Pierce Brosnan        Lee Tamahori
# Dr. No                            1962    Sean Connery       Terence Young
# For Your Eyes Only               bunnu           bunnu               bunnu
# From Russia with Love             1963    Sean Connery       Terence Young
# GoldenEye                         1995  Pierce Brosnan     Martin Campbell
# Goldfinger                        1964    Sean Connery        Guy Hamilton
# Licence to Kill                   1989  Timothy Dalton           John Glen
# ...

# %%
bond3.drop('You Only Live Twice', axis = 0)
# Out:
#                                   Year           Actor            Director  \
# Film
# A View to a Kill                 bunnu           bunnu               bunnu
# Casino Royale                     2006    Daniel Craig     Martin Campbell
# Casino Royale                     1967     David Niven          Ken Hughes
# Diamonds Are Forever              1971    Sean Connery        Guy Hamilton
# Die Another Day                   2002  Pierce Brosnan        Lee Tamahori
# Dr. No                            1962    Sean Connery       Terence Young
# For Your Eyes Only               bunnu           bunnu               bunnu
# From Russia with Love             1963    Sean Connery       Terence Young
# GoldenEye                         1995  Pierce Brosnan     Martin Campbell
# Goldfinger                        1964    Sean Connery        Guy Hamilton
# Licence to Kill                   1989  Timothy Dalton           John Glen
# ...

# %%
bond3.drop(columns=['Bond Actor Salary'],axis = 1,inplace=True)

# %%
bond3
# Out:
#                                   Year           Actor            Director  \
# Film
# A View to a Kill                 bunnu           bunnu               bunnu
# Casino Royale                     2006              DC     Martin Campbell
# Casino Royale                     1967     David Niven          Ken Hughes
# Diamonds Are Forever              1971    Sean Connery        Guy Hamilton
# Die Another Day                   2002  Pierce Brosnan        Lee Tamahori
# Dr. No                            1962    Sean Connery       Terence Young
# For Your Eyes Only               bunnu           bunnu               bunnu
# From Russia with Love             1963    Sean Connery       Terence Young
# GoldenEye                         1995  Pierce Brosnan     Martin Campbell
# Goldfinger                        1964    Sean Connery        Guy Hamilton
# Licence to Kill                   1989  Timothy Dalton           John Glen
# ...

# %%
#pop
Budget = bond3.pop('Budget')
bond3
# Out:
#                                   Year           Actor            Director  \
# Film
# A View to a Kill                 bunnu           bunnu               bunnu
# Casino Royale                     2006              DC     Martin Campbell
# Casino Royale                     1967     David Niven          Ken Hughes
# Diamonds Are Forever              1971    Sean Connery        Guy Hamilton
# Die Another Day                   2002  Pierce Brosnan        Lee Tamahori
# Dr. No                            1962    Sean Connery       Terence Young
# For Your Eyes Only               bunnu           bunnu               bunnu
# From Russia with Love             1963    Sean Connery       Terence Young
# GoldenEye                         1995  Pierce Brosnan     Martin Campbell
# Goldfinger                        1964    Sean Connery        Guy Hamilton
# Licence to Kill                   1989  Timothy Dalton           John Glen
# ...

# %%
Budget
# Out:
# Film
# A View to a Kill                   bunnu
# Casino Royale                      145.3
# Casino Royale                       85.0
# Diamonds Are Forever                34.7
# Die Another Day                    154.2
# Dr. No                               7.0
# For Your Eyes Only                 bunnu
# From Russia with Love               12.6
# GoldenEye                           76.9
# Goldfinger                          18.6
# Licence to Kill                     56.7
# Live and Let Die                   bunnu
# Moonraker                          bunnu
# Never Say Never Again               86.0
# Octopussy                          bunnu
# On Her Majesty's Secret Service     37.3
# Quantum of Solace                  181.4
# Skyfall                            170.2
# Spectre                            206.3
# The Living Daylights                68.8
# The Man with the Golden Gun        bunnu
# The Spy Who Loved Me               bunnu
# The World Is Not Enough            158.3
# ...

# %%
#del bond3['year']

# %%
#random

# %%
bond3.sample(n=2)
bond3.sample(frac= 0.25)
# Out:
#                                   Year           Actor         Director  \
# Film
# Skyfall                           2012              DC       Sam Mendes
# Casino Royale                     1967     David Niven       Ken Hughes
# From Russia with Love             1963    Sean Connery    Terence Young
# On Her Majesty's Secret Service   1969  George Lazenby    Peter R. Hunt
# GoldenEye                         1995  Pierce Brosnan  Martin Campbell
# A View to a Kill                 bunnu           bunnu            bunnu
#
#                                 Box Office
# Film
# Skyfall                              943.5
# Casino Royale                        315.0
# From Russia with Love                543.8
# On Her Majesty's Secret Service      291.5
# GoldenEye                            518.5
# A View to a Kill                     bunnu

# %%
#nsmallest and nlargest

# %%
bond4 = pd.read_csv('jamesbond.csv', index_col='Film')
bond4.nlargest(3,columns='Box Office')
bond4['Box Office'].nlargest(4)
# Out:
# Film
# Skyfall        943.5
# Thunderball    848.1
# Goldfinger     820.4
# Spectre        726.7
# Name: Box Office, dtype: float64

# %%
#filter

# %%
bond4
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond4.where(bond4['Actor']=='Sean Connery') #no [] in where
# Out:
#                                    Year         Actor        Director  \
# Film
# Dr. No                           1962.0  Sean Connery   Terence Young
# From Russia with Love            1963.0  Sean Connery   Terence Young
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Thunderball                      1965.0  Sean Connery   Terence Young
# Casino Royale                       NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Live and Let Die                    NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# ...

# %%
#query filter method no space in cols

# %%
bond4.columns = [i.replace(' ','_') for i in bond4.columns]

# %%
bond4
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond4.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# You Only Live Twice                  4.4
# Diamonds Are Forever                 5.8
# ...

# %%
bond4.query('Actor in ["Sean Connery","Daniel Craig"]')
# Out:
#                        Year         Actor         Director  Box_Office  \
# Film
# Dr. No                 1962  Sean Connery    Terence Young       448.8
# From Russia with Love  1963  Sean Connery    Terence Young       543.8
# Goldfinger             1964  Sean Connery     Guy Hamilton       820.4
# Thunderball            1965  Sean Connery    Terence Young       848.1
# You Only Live Twice    1967  Sean Connery    Lewis Gilbert       514.2
# Diamonds Are Forever   1971  Sean Connery     Guy Hamilton       442.5
# Never Say Never Again  1983  Sean Connery   Irvin Kershner       380.0
# Casino Royale          2006  Daniel Craig  Martin Campbell       581.5
# Quantum of Solace      2008  Daniel Craig     Marc Forster       514.2
# Skyfall                2012  Daniel Craig       Sam Mendes       943.5
# Spectre                2015  Daniel Craig       Sam Mendes       726.7
#
#                        Budget  Bond_Actor_Salary
# Film
# Dr. No                    7.0                0.6
# ...

# %%
#fx in df

# %%
def MM(num):
    return str(num)+"M"

# %%
bond4['Box_Office'].apply(MM)
# Out:
# Film
# Dr. No                             448.8M
# From Russia with Love              543.8M
# Goldfinger                         820.4M
# Thunderball                        848.1M
# Casino Royale                      315.0M
# You Only Live Twice                514.2M
# On Her Majesty's Secret Service    291.5M
# Diamonds Are Forever               442.5M
# Live and Let Die                   460.3M
# The Man with the Golden Gun        334.0M
# The Spy Who Loved Me               533.0M
# Moonraker                          535.0M
# For Your Eyes Only                 449.4M
# Never Say Never Again              380.0M
# Octopussy                          373.8M
# A View to a Kill                   275.2M
# The Living Daylights               313.5M
# Licence to Kill                    250.9M
# GoldenEye                          518.5M
# Tomorrow Never Dies                463.2M
# The World Is Not Enough            439.5M
# Die Another Day                    465.4M
# ...

# %%
col = ['Budget','Bond_Actor_Salary']
for i in col:
    bond4[i]=bond4[i].apply(MM)

# %%
bond4['Box_Office']=bond4['Box_Office'].astype('int')
bond4
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
def rating(row):
    a = row[1]
    b = row[3]
    if b > 500:
        return 'Good Movie'
    else:
        return 'Bad'

# %%
bond4.apply(rating,axis="columns")
# Out:
# Film
# Dr. No                                    Bad
# From Russia with Love              Good Movie
# Goldfinger                         Good Movie
# Thunderball                        Good Movie
# Casino Royale                             Bad
# You Only Live Twice                Good Movie
# On Her Majesty's Secret Service           Bad
# Diamonds Are Forever                      Bad
# Live and Let Die                          Bad
# The Man with the Golden Gun               Bad
# The Spy Who Loved Me               Good Movie
# Moonraker                          Good Movie
# For Your Eyes Only                        Bad
# Never Say Never Again                     Bad
# Octopussy                                 Bad
# A View to a Kill                          Bad
# The Living Daylights                      Bad
# Licence to Kill                           Bad
# GoldenEye                          Good Movie
# Tomorrow Never Dies                       Bad
# ...

# %%
bond4
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
copyy = bond4['Actor'].copy()

# %%
copyy['Spectre'] = 'DC'

# %%
copyy
# Out:
# Film
# Dr. No                               Sean Connery
# From Russia with Love                Sean Connery
# Goldfinger                           Sean Connery
# Thunderball                          Sean Connery
# Casino Royale                         David Niven
# You Only Live Twice                  Sean Connery
# On Her Majesty's Secret Service    George Lazenby
# Diamonds Are Forever                 Sean Connery
# Live and Let Die                      Roger Moore
# The Man with the Golden Gun           Roger Moore
# The Spy Who Loved Me                  Roger Moore
# Moonraker                             Roger Moore
# For Your Eyes Only                    Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# A View to a Kill                      Roger Moore
# The Living Daylights               Timothy Dalton
# Licence to Kill                    Timothy Dalton
# GoldenEye                          Pierce Brosnan
# ...

# %%
bond4
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
copyy2 = bond4['Director']

# %%
copyy2['Spectre'] = 'SM'
# Out:
# C:\Users\Prabh\AppData\Local\Temp/ipykernel_5784/404799437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   copyy2['Spectre'] = 'SM'

# %%
copyy2
# Out:
# Film
# Dr. No                                  Terence Young
# From Russia with Love                   Terence Young
# Goldfinger                               Guy Hamilton
# Thunderball                             Terence Young
# Casino Royale                              Ken Hughes
# You Only Live Twice                     Lewis Gilbert
# On Her Majesty's Secret Service         Peter R. Hunt
# Diamonds Are Forever                     Guy Hamilton
# Live and Let Die                         Guy Hamilton
# The Man with the Golden Gun              Guy Hamilton
# The Spy Who Loved Me                    Lewis Gilbert
# Moonraker                               Lewis Gilbert
# For Your Eyes Only                          John Glen
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# A View to a Kill                            John Glen
# The Living Daylights                        John Glen
# ...

# %%
bond4
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...
